# %%
import requests
import json
import pandas as pd

# %%
url = 'https://gwpre.sina.cn/interface/fymap2020_data.json?1582592919476'

# %%
#get response as string
file = requests.get(url)

# %%
#read data from file 
data = json.loads(file.text)['data']

# %%
province = pd.DataFrame(data['list']).set_index('name')
province = province.drop(['city','adddaily','ename','hejian','susNum','deathNum','cureNum','conadd'],axis=1)
province['value'] = province['value'].apply(int)
province = province.sort_values(by='value',ascending=False)

# %%
province.head()
# Out:
#       value
# name
# 湖北    64786
# 广东     1347
# 河南     1271
# 浙江     1205
# 湖南     1016

# %%
world = pd.DataFrame(data['worldlist']).set_index('name')
world = world.drop(['citycode','susNum','deathNum','cureNum'],axis=1)
world['value'] = world['value'].apply(int)
world = world.sort_values(by='value',ascending=False)

# %%
world.head()
# Out:
#       value
# name
# 中国    77779
# 韩国      893
# 日本      851
# 意大利     229
# 新加坡      90

# %%
data['list']
# Out:
# [{'name': '北京',
#   'ename': 'beijing',
#   'value': '400',
#   'conadd': 1,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '4',
#   'cureNum': '215',
#   'adddaily': {'conadd': '+1',
#    'deathadd': '+0',
#    'cureadd': '+17',
#    'conadd_n': 1,
#    'deathadd_n': 0,
#    'cureadd_n': 17},
#   'city': [{'name': '东城区',
#     'conNum': '13',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '东城区',
#     'citycode': 'CN11010100000000'},
#    {'name': '西城区',
#     'conNum': '53',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '西城区',
#     'citycode': 'CN11010200000000'},
#    {'name': '朝阳区',
#     'conNum': '61',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '朝阳区',
#     'citycode': 'CN11010500000000'},
#    {'name': '海淀区',
#     'conNum': '62',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '海淀区',
#     'citycode': 'CN11010800000000'},
#    {'name': '丰台区',
#     'conNum': '41',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '丰台区',
#     'citycode': 'CN11010600000000'},
#    {'name': '石景山区',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '石景山区',
#     'citycode': 'CN11010700000000'},
#    {'name': '门头沟区',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '门头沟区',
#     'citycode': 'CN11010900000000'},
#    {'name': '房山区',
#     'conNum': '16',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '房山区',
#     'citycode': 'CN11011100000000'},
#    {'name': '通州区',
#     'conNum': '19',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '通州区',
#     'citycode': 'CN11011200000000'},
#    {'name': '顺义区',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '顺义区',
#     'citycode': 'CN11011300000000'},
#    {'name': '昌平区',
#     'conNum': '29',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '昌平区',
#     'citycode': 'CN11011400000000'},
#    {'name': '大兴区',
#     'conNum': '39',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'mapName': '大兴区',
#     'citycode': 'CN11011500000000'},
#    {'name': '怀柔区',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '怀柔区',
#     'citycode': 'CN11011600000000'},
#    {'name': '密云区',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '密云区',
#     'citycode': 'CN11011800000000'},
#    {'name': '延庆区',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '延庆区',
#     'citycode': 'CN11011900000000'},
#    {'name': '外地来京人员',
#     'conNum': '25',
#     'conadd': 0,
#     'hejian': 1,
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''}]},
#  {'name': '湖北',
#   'ename': 'hubei',
#   'value': '64786',
#   'conadd': 499,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '2563',
#   'cureNum': '18877',
#   'adddaily': {'conadd': '+499',
#    'deathadd': '+68',
#    'cureadd': '+2139',
#    'conadd_n': 499,
#    'deathadd_n': 68,
#    'cureadd_n': 2139},
#   'city': [{'name': '武汉',
#     'conNum': '47071',
#     'conadd': 464,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10337',
#     'deathNum': '2043',
#     'mapName': '武汉市',
#     'citycode': 'CN42010000000000'},
#    {'name': '黄冈',
#     'conNum': '2904',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1760',
#     'deathNum': '106',
#     'mapName': '黄冈市',
#     'citycode': 'CN42110000000000'},
#    {'name': '孝感',
#     'conNum': '3482',
#     'conadd': 17,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1328',
#     'deathNum': '110',
#     'mapName': '孝感市',
#     'citycode': 'CN42090000000000'},
#    {'name': '荆门',
#     'conNum': '920',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '432',
#     'deathNum': '37',
#     'mapName': '荆门市',
#     'citycode': 'CN42080000000000'},
#    {'name': '咸宁',
#     'conNum': '836',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '504',
#     'deathNum': '11',
#     'mapName': '咸宁市',
#     'citycode': 'CN42120000000000'},
#    {'name': '荆州',
#     'conNum': '1576',
#     'conadd': 2,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '776',
#     'deathNum': '42',
#     'mapName': '荆州市',
#     'citycode': 'CN42100000000000'},
#    {'name': '襄阳',
#     'conNum': '1175',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '593',
#     'deathNum': '30',
#     'mapName': '襄阳市',
#     'citycode': 'CN42060000000000'},
#    {'name': '随州',
#     'conNum': '1305',
#     'conadd': 2,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '601',
#     'deathNum': '36',
#     'mapName': '随州市',
#     'citycode': 'CN42130000000000'},
#    {'name': '十堰',
#     'conNum': '671',
#     'conadd': 2,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '315',
#     'deathNum': '3',
#     'mapName': '十堰市',
#     'citycode': 'CN42030000000000'},
#    {'name': '鄂州',
#     'conNum': '1385',
#     'conadd': 2,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '496',
#     'deathNum': '41',
#     'mapName': '鄂州市',
#     'citycode': 'CN42070000000000'},
#    {'name': '黄石',
#     'conNum': '1008',
#     'conadd': 3,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '557',
#     'deathNum': '31',
#     'mapName': '黄石市',
#     'citycode': 'CN42020000000000'},
#    {'name': '宜昌',
#     'conNum': '926',
#     'conadd': 2,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '328',
#     'deathNum': '29',
#     'mapName': '宜昌市',
#     'citycode': 'CN42050000000000'},
#    {'name': '恩施州',
#     'conNum': '251',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '151',
#     'deathNum': '4',
#     'mapName': '恩施土家族苗族自治州',
#     'citycode': 'CN42280000000000'},
#    {'name': '仙桃',
#     'conNum': '575',
#     'conadd': 2,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '316',
#     'deathNum': '19',
#     'mapName': '仙桃市',
#     'citycode': 'CN42900400000000'},
#    {'name': '天门',
#     'conNum': '495',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '282',
#     'deathNum': '13',
#     'mapName': '天门市',
#     'citycode': 'CN42900600000000'},
#    {'name': '潜江',
#     'conNum': '195',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '91',
#     'deathNum': '8',
#     'mapName': '潜江市',
#     'citycode': 'CN42900500000000'},
#    {'name': '神农架林区',
#     'conNum': '11',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '神农架林区',
#     'citycode': 'CN42902100000000'}]},
#  {'name': '广东',
#   'ename': 'guangdong',
#   'value': '1347',
#   'conadd': 2,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '7',
#   'cureNum': '807',
#   'adddaily': {'conadd': '+2',
#    'deathadd': '+1',
#    'cureadd': '+35',
#    'conadd_n': 2,
#    'deathadd_n': 1,
#    'cureadd_n': 35},
#   'city': [{'name': '深圳',
#     'conNum': '417',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '249',
#     'deathNum': '3',
#     'mapName': '深圳市',
#     'citycode': 'CN44030000000000'},
#    {'name': '广州',
#     'conNum': '346',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '210',
#     'deathNum': '1',
#     'mapName': '广州市',
#     'citycode': 'CN44010000000000'},
#    {'name': '珠海',
#     'conNum': '98',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '56',
#     'deathNum': '1',
#     'mapName': '珠海市',
#     'citycode': 'CN44040000000000'},
#    {'name': '佛山',
#     'conNum': '84',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '36',
#     'deathNum': '0',
#     'mapName': '佛山市',
#     'citycode': 'CN44060000000000'},
#    {'name': '东莞',
#     'conNum': '97',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '40',
#     'deathNum': '1',
#     'mapName': '东莞市',
#     'citycode': 'CN44190000000000'},
#    {'name': '中山',
#     'conNum': '66',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '53',
#     'deathNum': '0',
#     'mapName': '中山市',
#     'citycode': 'CN44200000000000'},
#    {'name': '惠州',
#     'conNum': '62',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '49',
#     'deathNum': '0',
#     'mapName': '惠州市',
#     'citycode': 'CN44130000000000'},
#    {'name': '汕头',
#     'conNum': '25',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '21',
#     'deathNum': '0',
#     'mapName': '汕头市',
#     'citycode': 'CN44050000000000'},
#    {'name': '江门',
#     'conNum': '23',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '江门市',
#     'citycode': 'CN44070000000000'},
#    {'name': '湛江',
#     'conNum': '22',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'mapName': '湛江市',
#     'citycode': 'CN44080000000000'},
#    {'name': '肇庆',
#     'conNum': '19',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '1',
#     'mapName': '肇庆市',
#     'citycode': 'CN44120000000000'},
#    {'name': '梅州',
#     'conNum': '16',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '梅州市',
#     'citycode': 'CN44140000000000'},
#    {'name': '阳江',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '阳江市',
#     'citycode': 'CN44170000000000'},
#    {'name': '茂名',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '茂名市',
#     'citycode': 'CN44090000000000'},
#    {'name': '清远',
#     'conNum': '12',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '12',
#     'deathNum': '0',
#     'mapName': '清远市',
#     'citycode': 'CN44180000000000'},
#    {'name': '揭阳',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '揭阳市',
#     'citycode': 'CN44520000000000'},
#    {'name': '韶关',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '韶关市',
#     'citycode': 'CN44020000000000'},
#    {'name': '汕尾',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '汕尾市',
#     'citycode': 'CN44150000000000'},
#    {'name': '潮州',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '潮州市',
#     'citycode': 'CN44510000000000'},
#    {'name': '河源',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '河源市',
#     'citycode': 'CN44160000000000'}]},
#  {'name': '浙江',
#   'ename': 'zhejiang',
#   'value': '1205',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '1',
#   'cureNum': '794',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+29',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 29},
#   'city': [{'name': '杭州',
#     'conNum': '169',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '136',
#     'deathNum': '0',
#     'mapName': '杭州市',
#     'citycode': 'CN33010000000000'},
#    {'name': '宁波',
#     'conNum': '157',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '121',
#     'deathNum': '0',
#     'mapName': '宁波市',
#     'citycode': 'CN33020000000000'},
#    {'name': '温州',
#     'conNum': '504',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '306',
#     'deathNum': '1',
#     'mapName': '温州市',
#     'citycode': 'CN33030000000000'},
#    {'name': '湖州',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '湖州市',
#     'citycode': 'CN33050000000000'},
#    {'name': '嘉兴',
#     'conNum': '45',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '28',
#     'deathNum': '0',
#     'mapName': '嘉兴市',
#     'citycode': 'CN33040000000000'},
#    {'name': '绍兴',
#     'conNum': '42',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '30',
#     'deathNum': '0',
#     'mapName': '绍兴市',
#     'citycode': 'CN33060000000000'},
#    {'name': '金华',
#     'conNum': '55',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '39',
#     'deathNum': '0',
#     'mapName': '金华市',
#     'citycode': 'CN33070000000000'},
#    {'name': '衢州',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '衢州市',
#     'citycode': 'CN33080000000000'},
#    {'name': '舟山',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '舟山市',
#     'citycode': 'CN33090000000000'},
#    {'name': '台州',
#     'conNum': '146',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '98',
#     'deathNum': '0',
#     'mapName': '台州市',
#     'citycode': 'CN33100000000000'},
#    {'name': '丽水',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'mapName': '丽水市',
#     'citycode': 'CN33110000000000'},
#    {'name': '省十里丰监狱',
#     'conNum': '36',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '杭州市',
#     'citycode': 'CN33010000000000'}]},
#  {'name': '河南',
#   'ename': 'henan',
#   'value': '1271',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '19',
#   'cureNum': '989',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+59',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 59},
#   'city': [{'name': '信阳市',
#     'conNum': '274',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '197',
#     'deathNum': '2',
#     'mapName': '信阳市',
#     'citycode': 'CN41150000000000'},
#    {'name': '南阳市',
#     'conNum': '155',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '124',
#     'deathNum': '3',
#     'mapName': '南阳市',
#     'citycode': 'CN41130000000000'},
#    {'name': '郑州市',
#     'conNum': '157',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '118',
#     'deathNum': '0',
#     'mapName': '郑州市',
#     'citycode': 'CN41010000000000'},
#    {'name': '驻马店市',
#     'conNum': '139',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '124',
#     'deathNum': '0',
#     'mapName': '驻马店市',
#     'citycode': 'CN41170000000000'},
#    {'name': '商丘市',
#     'conNum': '91',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '75',
#     'deathNum': '3',
#     'mapName': '商丘市',
#     'citycode': 'CN41140000000000'},
#    {'name': '周口市',
#     'conNum': '76',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '51',
#     'deathNum': '0',
#     'mapName': '周口市',
#     'citycode': 'CN41160000000000'},
#    {'name': '平顶山市',
#     'conNum': '58',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '44',
#     'deathNum': '1',
#     'mapName': '平顶山市',
#     'citycode': 'CN41040000000000'},
#    {'name': '新乡市',
#     'conNum': '57',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '48',
#     'deathNum': '3',
#     'mapName': '新乡市',
#     'citycode': 'CN41070000000000'},
#    {'name': '安阳市',
#     'conNum': '53',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '41',
#     'deathNum': '0',
#     'mapName': '安阳市',
#     'citycode': 'CN41050000000000'},
#    {'name': '许昌市',
#     'conNum': '39',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '32',
#     'deathNum': '0',
#     'mapName': '许昌市',
#     'citycode': 'CN41100000000000'},
#    {'name': '漯河市',
#     'conNum': '35',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '23',
#     'deathNum': '0',
#     'mapName': '漯河市',
#     'citycode': 'CN41110000000000'},
#    {'name': '焦作市',
#     'conNum': '32',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '24',
#     'deathNum': '1',
#     'mapName': '焦作市',
#     'citycode': 'CN41080000000000'},
#    {'name': '洛阳市',
#     'conNum': '31',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '20',
#     'deathNum': '1',
#     'mapName': '洛阳市',
#     'citycode': 'CN41030000000000'},
#    {'name': '开封市',
#     'conNum': '26',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'mapName': '开封市',
#     'citycode': 'CN41020000000000'},
#    {'name': '鹤壁市',
#     'conNum': '19',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '鹤壁市',
#     'citycode': 'CN41060000000000'},
#    {'name': '濮阳市',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '濮阳市',
#     'citycode': 'CN41090000000000'},
#    {'name': '三门峡市',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '1',
#     'mapName': '三门峡市',
#     'citycode': 'CN41120000000000'},
#    {'name': '济源示范区',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '济源市',
#     'citycode': 'CN41900100000000'}]},
#  {'name': '湖南',
#   'ename': 'hunan',
#   'value': '1016',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '4',
#   'cureNum': '751',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+30',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 30},
#   'city': [{'name': '长沙市',
#     'conNum': '242',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '152',
#     'deathNum': '2',
#     'mapName': '长沙市',
#     'citycode': 'CN43010000000000'},
#    {'name': '衡阳市',
#     'conNum': '48',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '38',
#     'deathNum': '0',
#     'mapName': '衡阳市',
#     'citycode': 'CN43040000000000'},
#    {'name': '株洲市',
#     'conNum': '80',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '52',
#     'deathNum': '0',
#     'mapName': '株洲市',
#     'citycode': 'CN43020000000000'},
#    {'name': '湘潭市',
#     'conNum': '36',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '26',
#     'deathNum': '0',
#     'mapName': '湘潭市',
#     'citycode': 'CN43030000000000'},
#    {'name': '邵阳市',
#     'conNum': '102',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '88',
#     'deathNum': '1',
#     'mapName': '邵阳市',
#     'citycode': 'CN43050000000000'},
#    {'name': '岳阳市',
#     'conNum': '156',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '98',
#     'deathNum': '1',
#     'mapName': '岳阳市',
#     'citycode': 'CN43060000000000'},
#    {'name': '常德市',
#     'conNum': '82',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '62',
#     'deathNum': '0',
#     'mapName': '常德市',
#     'citycode': 'CN43070000000000'},
#    {'name': '张家界市',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '张家界市',
#     'citycode': 'CN43080000000000'},
#    {'name': '益阳市',
#     'conNum': '59',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '55',
#     'deathNum': '0',
#     'mapName': '益阳市',
#     'citycode': 'CN43090000000000'},
#    {'name': '郴州市',
#     'conNum': '39',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '31',
#     'deathNum': '0',
#     'mapName': '郴州市',
#     'citycode': 'CN43100000000000'},
#    {'name': '永州市',
#     'conNum': '43',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '41',
#     'deathNum': '0',
#     'mapName': '永州市',
#     'citycode': 'CN43110000000000'},
#    {'name': '怀化市',
#     'conNum': '40',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '39',
#     'deathNum': '0',
#     'mapName': '怀化市',
#     'citycode': 'CN43120000000000'},
#    {'name': '娄底市',
#     'conNum': '76',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '56',
#     'deathNum': '0',
#     'mapName': '娄底市',
#     'citycode': 'CN43130000000000'},
#    {'name': '湘西自治州',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'mapName': '湘西土家族苗族自治州',
#     'citycode': 'CN43310000000000'}]},
#  {'name': '重庆',
#   'ename': 'chongqing',
#   'value': '576',
#   'conadd': 1,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '6',
#   'cureNum': '349',
#   'adddaily': {'conadd': '+1',
#    'deathadd': '+0',
#    'cureadd': '+14',
#    'conadd_n': 1,
#    'deathadd_n': 0,
#    'cureadd_n': 14},
#   'city': [{'name': '万州',
#     'conNum': '118',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '72',
#     'deathNum': '4',
#     'mapName': '万州区',
#     'citycode': 'CN50010100000000'},
#    {'name': '黔江',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '黔江区',
#     'citycode': 'CN50011400000000'},
#    {'name': '涪陵',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '涪陵区',
#     'citycode': 'CN50010200000000'},
#    {'name': '渝中',
#     'conNum': '20',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'mapName': '渝中区',
#     'citycode': 'CN50010300000000'},
#    {'name': '大渡口',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '大渡口区',
#     'citycode': 'CN50010400000000'},
#    {'name': '江北',
#     'conNum': '28',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '江北区',
#     'citycode': 'CN50010500000000'},
#    {'name': '沙坪坝',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '沙坪坝区',
#     'citycode': 'CN50010600000000'},
#    {'name': '九龙坡',
#     'conNum': '21',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '1',
#     'mapName': '九龙坡区',
#     'citycode': 'CN50010700000000'},
#    {'name': '南岸',
#     'conNum': '15',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '南岸区',
#     'citycode': 'CN50010800000000'},
#    {'name': '渝北',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '渝北区',
#     'citycode': 'CN50011200000000'},
#    {'name': '巴南',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '巴南区',
#     'citycode': 'CN50011300000000'},
#    {'name': '长寿',
#     'conNum': '22',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '长寿区',
#     'citycode': 'CN50011500000000'},
#    {'name': '江津',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '江津区',
#     'citycode': 'CN50011600000000'},
#    {'name': '合川',
#     'conNum': '23',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'mapName': '合川区',
#     'citycode': 'CN50011700000000'},
#    {'name': '永川',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '永川区',
#     'citycode': 'CN50011800000000'},
#    {'name': '綦江',
#     'conNum': '23',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '13',
#     'deathNum': '0',
#     'mapName': '綦江区',
#     'citycode': 'CN50011000000000'},
#    {'name': '大足',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '9',
#     'deathNum': '0',
#     'mapName': '大足区',
#     'citycode': 'CN50011100000000'},
#    {'name': '璧山',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '璧山区',
#     'citycode': 'CN50012000000000'},
#    {'name': '铜梁',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '铜梁区',
#     'citycode': 'CN50015100000000'},
#    {'name': '潼南',
#     'conNum': '18',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '潼南区',
#     'citycode': 'CN50015200000000'},
#    {'name': '荣昌',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '荣昌区',
#     'citycode': 'CN50015300000000'},
#    {'name': '开州',
#     'conNum': '21',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '18',
#     'deathNum': '1',
#     'mapName': '开州区',
#     'citycode': 'CN50023400000000'},
#    {'name': '梁平',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '梁平区',
#     'citycode': 'CN50022800000000'},
#    {'name': '武隆',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '武隆区',
#     'citycode': 'CN50023200000000'},
#    {'name': '城口',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '城口县',
#     'citycode': 'CN50022900000000'},
#    {'name': '丰都',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '丰都县',
#     'citycode': 'CN50023000000000'},
#    {'name': '垫江',
#     'conNum': '20',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '垫江县',
#     'citycode': 'CN50023100000000'},
#    {'name': '忠县',
#     'conNum': '21',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'mapName': '忠县',
#     'citycode': 'CN50023300000000'},
#    {'name': '云阳',
#     'conNum': '25',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '21',
#     'deathNum': '0',
#     'mapName': '云阳县',
#     'citycode': 'CN50023500000000'},
#    {'name': '奉节',
#     'conNum': '22',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '12',
#     'deathNum': '0',
#     'mapName': '奉节县',
#     'citycode': 'CN50023600000000'},
#    {'name': '巫山',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '巫山县',
#     'citycode': 'CN50023700000000'},
#    {'name': '巫溪',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '巫溪县',
#     'citycode': 'CN50023800000000'},
#    {'name': '石柱',
#     'conNum': '15',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '石柱土家族自治县',
#     'citycode': 'CN50024000000000'},
#    {'name': '秀山',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '秀山土家族苗族自治县',
#     'citycode': 'CN50024100000000'},
#    {'name': '酉阳',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '酉阳土家族苗族自治县',
#     'citycode': 'CN50024200000000'},
#    {'name': '彭水',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '彭水苗族土家族自治县',
#     'citycode': 'CN50024300000000'},
#    {'name': '两江新区',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''},
#    {'name': '高新区',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''},
#    {'name': '万盛',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''},
#    {'name': '未明确地区',
#     'conNum': '0',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''}]},
#  {'name': '安徽',
#   'ename': 'anhui',
#   'value': '989',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '6',
#   'cureNum': '692',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+44',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 44},
#   'city': [{'name': '阜阳',
#     'conNum': '155',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '104',
#     'deathNum': '0',
#     'mapName': '阜阳市',
#     'citycode': 'CN34120000000000'},
#    {'name': '合肥',
#     'conNum': '174',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '119',
#     'deathNum': '1',
#     'mapName': '合肥市',
#     'citycode': 'CN34010000000000'},
#    {'name': '马鞍山',
#     'conNum': '38',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '20',
#     'deathNum': '0',
#     'mapName': '马鞍山市',
#     'citycode': 'CN34050000000000'},
#    {'name': '芜湖',
#     'conNum': '33',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '27',
#     'deathNum': '0',
#     'mapName': '芜湖市',
#     'citycode': 'CN34020000000000'},
#    {'name': '铜陵',
#     'conNum': '29',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'mapName': '铜陵市',
#     'citycode': 'CN34070000000000'},
#    {'name': '安庆',
#     'conNum': '83',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '69',
#     'deathNum': '0',
#     'mapName': '安庆市',
#     'citycode': 'CN34080000000000'},
#    {'name': '亳州',
#     'conNum': '108',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '81',
#     'deathNum': '0',
#     'mapName': '亳州市',
#     'citycode': 'CN34160000000000'},
#    {'name': '黄山',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '黄山市',
#     'citycode': 'CN34100000000000'},
#    {'name': '滁州',
#     'conNum': '13',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '9',
#     'deathNum': '0',
#     'mapName': '滁州市',
#     'citycode': 'CN34110000000000'},
#    {'name': '六安',
#     'conNum': '69',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '45',
#     'deathNum': '0',
#     'mapName': '六安市',
#     'citycode': 'CN34150000000000'},
#    {'name': '宿州',
#     'conNum': '41',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '29',
#     'deathNum': '0',
#     'mapName': '宿州市',
#     'citycode': 'CN34130000000000'},
#    {'name': '蚌埠',
#     'conNum': '160',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '113',
#     'deathNum': '5',
#     'mapName': '蚌埠市',
#     'citycode': 'CN34030000000000'},
#    {'name': '淮南',
#     'conNum': '27',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'mapName': '淮南市',
#     'citycode': 'CN34040000000000'},
#    {'name': '宣城',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '宣城市',
#     'citycode': 'CN34180000000000'},
#    {'name': '淮北',
#     'conNum': '27',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '17',
#     'deathNum': '0',
#     'mapName': '淮北市',
#     'citycode': 'CN34060000000000'},
#    {'name': '池州',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '13',
#     'deathNum': '0',
#     'mapName': '池州市',
#     'citycode': 'CN34170000000000'}]},
#  {'name': '四川',
#   'ename': 'sichuan',
#   'value': '529',
#   'conadd': 2,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '3',
#   'cureNum': '278',
#   'adddaily': {'conadd': '+2',
#    'deathadd': '+0',
#    'cureadd': '+15',
#    'conadd_n': 2,
#    'deathadd_n': 0,
#    'cureadd_n': 15},
#   'city': [{'name': '成都',
#     'conNum': '143',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '79',
#     'deathNum': '3',
#     'mapName': '成都市',
#     'citycode': 'CN51010000000000'},
#    {'name': '自贡',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '自贡市',
#     'citycode': 'CN51030000000000'},
#    {'name': '攀枝花',
#     'conNum': '16',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'mapName': '攀枝花市',
#     'citycode': 'CN51040000000000'},
#    {'name': '泸州',
#     'conNum': '24',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '泸州市',
#     'citycode': 'CN51050000000000'},
#    {'name': '德阳',
#     'conNum': '18',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '7',
#     'deathNum': '0',
#     'mapName': '德阳市',
#     'citycode': 'CN51060000000000'},
#    {'name': '绵阳',
#     'conNum': '22',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '12',
#     'deathNum': '0',
#     'mapName': '绵阳市',
#     'citycode': 'CN51070000000000'},
#    {'name': '广元',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '广元市',
#     'citycode': 'CN51080000000000'},
#    {'name': '遂宁',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '遂宁市',
#     'citycode': 'CN51090000000000'},
#    {'name': '内江',
#     'conNum': '22',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '13',
#     'deathNum': '0',
#     'mapName': '内江市',
#     'citycode': 'CN51100000000000'},
#    {'name': '乐山',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '乐山市',
#     'citycode': 'CN51110000000000'},
#    {'name': '南充',
#     'conNum': '39',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '22',
#     'deathNum': '0',
#     'mapName': '南充市',
#     'citycode': 'CN51130000000000'},
#    {'name': '宜宾',
#     'conNum': '12',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'mapName': '宜宾市',
#     'citycode': 'CN51150000000000'},
#    {'name': '广安',
#     'conNum': '30',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '20',
#     'deathNum': '0',
#     'mapName': '广安市',
#     'citycode': 'CN51160000000000'},
#    {'name': '达州',
#     'conNum': '42',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '15',
#     'deathNum': '0',
#     'mapName': '达州市',
#     'citycode': 'CN51170000000000'},
#    {'name': '巴中',
#     'conNum': '24',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '巴中市',
#     'citycode': 'CN51190000000000'},
#    {'name': '雅安',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '雅安市',
#     'citycode': 'CN51180000000000'},
#    {'name': '眉山',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '眉山市',
#     'citycode': 'CN51140000000000'},
#    {'name': '资阳',
#     'conNum': '4',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '资阳市',
#     'citycode': 'CN51200000000000'},
#    {'name': '阿坝州',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '阿坝藏族羌族自治州',
#     'citycode': 'CN51320000000000'},
#    {'name': '甘孜州',
#     'conNum': '69',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'mapName': '甘孜藏族自治州',
#     'citycode': 'CN51330000000000'},
#    {'name': '凉山州',
#     'conNum': '13',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'mapName': '凉山彝族自治州',
#     'citycode': 'CN51340000000000'}]},
#  {'name': '山东',
#   'ename': 'shandong',
#   'value': '755',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '6',
#   'cureNum': '343',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+2',
#    'cureadd': '+18',
#    'conadd_n': 0,
#    'deathadd_n': 2,
#    'cureadd_n': 18},
#   'city': [{'name': '济南',
#     'conNum': '47',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '24',
#     'deathNum': '0',
#     'mapName': '济南市',
#     'citycode': 'CN37010000000000'},
#    {'name': '青岛',
#     'conNum': '60',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '38',
#     'deathNum': '1',
#     'mapName': '青岛市',
#     'citycode': 'CN37020000000000'},
#    {'name': '淄博',
#     'conNum': '30',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '16',
#     'deathNum': '1',
#     'mapName': '淄博市',
#     'citycode': 'CN37030000000000'},
#    {'name': '枣庄',
#     'conNum': '24',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '19',
#     'deathNum': '0',
#     'mapName': '枣庄市',
#     'citycode': 'CN37040000000000'},
#    {'name': '烟台',
#     'conNum': '47',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '20',
#     'deathNum': '0',
#     'mapName': '烟台市',
#     'citycode': 'CN37060000000000'},
#    {'name': '潍坊',
#     'conNum': '44',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '22',
#     'deathNum': '0',
#     'mapName': '潍坊市',
#     'citycode': 'CN37070000000000'},
#    {'name': '济宁',
#     'conNum': '257',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '34',
#     'deathNum': '0',
#     'mapName': '济宁市',
#     'citycode': 'CN37080000000000'},
#    {'name': '泰安',
#     'conNum': '35',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '22',
#     'deathNum': '2',
#     'mapName': '泰安市',
#     'citycode': 'CN37090000000000'},
#    {'name': '威海',
#     'conNum': '38',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '25',
#     'deathNum': '0',
#     'mapName': '威海市',
#     'citycode': 'CN37100000000000'},
#    {'name': '日照',
#     'conNum': '16',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '日照市',
#     'citycode': 'CN37110000000000'},
#    {'name': '临沂',
#     'conNum': '49',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '44',
#     'deathNum': '0',
#     'mapName': '临沂市',
#     'citycode': 'CN37130000000000'},
#    {'name': '德州',
#     'conNum': '37',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '15',
#     'deathNum': '2',
#     'mapName': '德州市',
#     'citycode': 'CN37140000000000'},
#    {'name': '聊城',
#     'conNum': '38',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '25',
#     'deathNum': '0',
#     'mapName': '聊城市',
#     'citycode': 'CN37150000000000'},
#    {'name': '滨州',
#     'conNum': '15',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'mapName': '滨州市',
#     'citycode': 'CN37160000000000'},
#    {'name': '菏泽',
#     'conNum': '18',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '17',
#     'deathNum': '0',
#     'mapName': '菏泽市',
#     'citycode': 'CN37170000000000'}]},
#  {'name': '吉林',
#   'ename': 'jilin',
#   'value': '93',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '19',
#   'deathNum': '1',
#   'cureNum': '60',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+6',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 6},
#   'city': [{'name': '长春',
#     'conNum': '45',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '32',
#     'deathNum': '0',
#     'mapName': '长春市',
#     'citycode': 'CN22010000000000'},
#    {'name': '四平',
#     'conNum': '15',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '9',
#     'deathNum': '1',
#     'mapName': '四平市',
#     'citycode': 'CN22030000000000'},
#    {'name': '吉林',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '吉林市',
#     'citycode': 'CN22020000000000'},
#    {'name': '公主岭',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '公主岭市',
#     'citycode': 'CNgzls00000000'},
#    {'name': '白城',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '白城市',
#     'citycode': 'CN22080000000000'},
#    {'name': '延边',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '延边朝鲜族自治州',
#     'citycode': 'CN22240000000000'},
#    {'name': '辽源',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '辽源市',
#     'citycode': 'CN22040000000000'},
#    {'name': '松原',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '松原市',
#     'citycode': 'CN22070000000000'},
#    {'name': '通化',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '通化市',
#     'citycode': 'CN22050000000000'},
#    {'name': '梅河口',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '梅河口市',
#     'citycode': 'CNmhks00000000'}]},
#  {'name': '福建',
#   'ename': 'fujian',
#   'value': '294',
#   'conadd': 1,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '1',
#   'cureNum': '188',
#   'adddaily': {'conadd': '+1',
#    'deathadd': '+0',
#    'cureadd': '+14',
#    'conadd_n': 1,
#    'deathadd_n': 0,
#    'cureadd_n': 14},
#   'city': [{'name': '福州',
#     'conNum': '71',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '56',
#     'deathNum': '1',
#     'mapName': '福州市',
#     'citycode': 'CN35010000000000'},
#    {'name': '莆田',
#     'conNum': '55',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '30',
#     'deathNum': '0',
#     'mapName': '莆田市',
#     'citycode': 'CN35030000000000'},
#    {'name': '漳州',
#     'conNum': '20',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'mapName': '漳州市',
#     'citycode': 'CN35060000000000'},
#    {'name': '泉州',
#     'conNum': '47',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '21',
#     'deathNum': '0',
#     'mapName': '泉州市',
#     'citycode': 'CN35050000000000'},
#    {'name': '三明',
#     'conNum': '14',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '三明市',
#     'citycode': 'CN35040000000000'},
#    {'name': '厦门',
#     'conNum': '35',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '27',
#     'deathNum': '0',
#     'mapName': '厦门市',
#     'citycode': 'CN35020000000000'},
#    {'name': '南平',
#     'conNum': '20',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '南平市',
#     'citycode': 'CN35070000000000'},
#    {'name': '龙岩',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '龙岩市',
#     'citycode': 'CN35080000000000'},
#    {'name': '宁德',
#     'conNum': '26',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '20',
#     'deathNum': '0',
#     'mapName': '宁德市',
#     'citycode': 'CN35090000000000'}]},
#  {'name': '江西',
#   'ename': 'jiangxi',
#   'value': '934',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '1',
#   'cureNum': '682',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+37',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 37},
#   'city': [{'name': '南昌',
#     'conNum': '229',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '184',
#     'deathNum': '0',
#     'mapName': '南昌市',
#     'citycode': 'CN36010000000000'},
#    {'name': '赣州',
#     'conNum': '76',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '53',
#     'deathNum': '1',
#     'mapName': '赣州市',
#     'citycode': 'CN36070000000000'},
#    {'name': '宜春',
#     'conNum': '106',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '84',
#     'deathNum': '0',
#     'mapName': '宜春市',
#     'citycode': 'CN36090000000000'},
#    {'name': '九江',
#     'conNum': '118',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '62',
#     'deathNum': '0',
#     'mapName': '九江市',
#     'citycode': 'CN36040000000000'},
#    {'name': '抚州',
#     'conNum': '72',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '52',
#     'deathNum': '0',
#     'mapName': '抚州市',
#     'citycode': 'CN36100000000000'},
#    {'name': '上饶',
#     'conNum': '123',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '97',
#     'deathNum': '0',
#     'mapName': '上饶市',
#     'citycode': 'CN36110000000000'},
#    {'name': '新余',
#     'conNum': '130',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '109',
#     'deathNum': '0',
#     'mapName': '新余市',
#     'citycode': 'CN36050000000000'},
#    {'name': '吉安',
#     'conNum': '22',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '12',
#     'deathNum': '0',
#     'mapName': '吉安市',
#     'citycode': 'CN36080000000000'},
#    {'name': '景德镇',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '景德镇市',
#     'citycode': 'CN36020000000000'},
#    {'name': '萍乡',
#     'conNum': '33',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'mapName': '萍乡市',
#     'citycode': 'CN36030000000000'},
#    {'name': '鹰潭',
#     'conNum': '18',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '鹰潭市',
#     'citycode': 'CN36060000000000'},
#    {'name': '赣江新区',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '南昌市',
#     'citycode': 'CN36010000000000'}]},
#  {'name': '江苏',
#   'ename': 'jiangsu',
#   'value': '631',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '458',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+31',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 31},
#   'city': [{'name': '南京',
#     'conNum': '93',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '57',
#     'deathNum': '0',
#     'mapName': '南京市',
#     'citycode': 'CN32010000000000'},
#    {'name': '无锡',
#     'conNum': '55',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '41',
#     'deathNum': '0',
#     'mapName': '无锡市',
#     'citycode': 'CN32020000000000'},
#    {'name': '徐州',
#     'conNum': '79',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '67',
#     'deathNum': '0',
#     'mapName': '徐州市',
#     'citycode': 'CN32030000000000'},
#    {'name': '常州',
#     'conNum': '51',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '41',
#     'deathNum': '0',
#     'mapName': '常州市',
#     'citycode': 'CN32040000000000'},
#    {'name': '苏州',
#     'conNum': '87',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '57',
#     'deathNum': '0',
#     'mapName': '苏州市',
#     'citycode': 'CN32050000000000'},
#    {'name': '南通',
#     'conNum': '40',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '34',
#     'deathNum': '0',
#     'mapName': '南通市',
#     'citycode': 'CN32060000000000'},
#    {'name': '连云港',
#     'conNum': '48',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '25',
#     'deathNum': '0',
#     'mapName': '连云港市',
#     'citycode': 'CN32070000000000'},
#    {'name': '淮安',
#     'conNum': '66',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '46',
#     'deathNum': '0',
# ...
#    {'name': '滨海新区',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '滨海新区',
#     'citycode': 'CN12011600000000'},
#    {'name': '北辰区',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '北辰区',
#     'citycode': 'CN12011300000000'},
#    {'name': '津南区',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '津南区',
#     'citycode': 'CN12011200000000'},
#    {'name': '武清区',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '武清区',
#     'citycode': 'CN12011400000000'}]},
#  {'name': '山西',
#   'ename': 'shanxi',
#   'value': '133',
#   'conadd': 1,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '94',
#   'adddaily': {'conadd': '+1',
#    'deathadd': '+0',
#    'cureadd': '+6',
#    'conadd_n': 1,
#    'deathadd_n': 0,
#    'cureadd_n': 6},
#   'city': [{'name': '太原',
#     'conNum': '20',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'mapName': '太原市',
#     'citycode': 'CN14010000000000'},
#    {'name': '大同',
#     'conNum': '12',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'mapName': '大同市',
#     'citycode': 'CN14020000000000'},
#    {'name': '阳泉',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '阳泉市',
#     'citycode': 'CN14030000000000'},
#    {'name': '长治',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '长治市',
#     'citycode': 'CN14040000000000'},
#    {'name': '晋城',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '晋城市',
#     'citycode': 'CN14050000000000'},
#    {'name': '朔州',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '朔州市',
#     'citycode': 'CN14060000000000'},
#    {'name': '晋中',
#     'conNum': '37',
#     'conadd': 1,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '23',
#     'deathNum': '0',
#     'mapName': '晋中市',
#     'citycode': 'CN14070000000000'},
#    {'name': '忻州',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '忻州市',
#     'citycode': 'CN14090000000000'},
#    {'name': '运城',
#     'conNum': '19',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '17',
#     'deathNum': '0',
#     'mapName': '运城市',
#     'citycode': 'CN14080000000000'},
#    {'name': '临汾',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '临汾市',
#     'citycode': 'CN14100000000000'},
#    {'name': '吕梁',
#     'conNum': '6',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '吕梁市',
#     'citycode': 'CN14110000000000'}]},
#  {'name': '甘肃',
#   'ename': 'gansu',
#   'value': '91',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '2',
#   'cureNum': '80',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+2',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 2},
#   'city': [{'name': '兰州',
#     'conNum': '36',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '31',
#     'deathNum': '2',
#     'mapName': '兰州市',
#     'citycode': 'CN62010000000000'},
#    {'name': '天水',
#     'conNum': '12',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '12',
#     'deathNum': '0',
#     'mapName': '天水市',
#     'citycode': 'CN62050000000000'},
#    {'name': '定西',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'mapName': '定西市',
#     'citycode': 'CN62110000000000'},
#    {'name': '平凉',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '平凉市',
#     'citycode': 'CN62080000000000'},
#    {'name': '甘南州',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'mapName': '甘南藏族自治州',
#     'citycode': 'CN62300000000000'},
#    {'name': '白银',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '白银市',
#     'citycode': 'CN62040000000000'},
#    {'name': '陇南',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '陇南市',
#     'citycode': 'CN62120000000000'},
#    {'name': '庆阳',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '庆阳市',
#     'citycode': 'CN62100000000000'},
#    {'name': '临夏州',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '临夏回族自治州',
#     'citycode': 'CN62290000000000'},
#    {'name': '张掖',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '张掖市',
#     'citycode': 'CN62070000000000'},
#    {'name': '金昌',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '金昌市',
#     'citycode': 'CN62030000000000'}]},
#  {'name': '内蒙古',
#   'ename': 'neimenggu',
#   'value': '75',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '34',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+4',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 4},
#   'city': [{'name': '鄂尔多斯',
#     'conNum': '11',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '9',
#     'deathNum': '0',
#     'mapName': '鄂尔多斯市',
#     'citycode': 'CN15060000000000'},
#    {'name': '包头',
#     'conNum': '11',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'mapName': '包头市',
#     'citycode': 'CN15020000000000'},
#    {'name': '锡林郭勒',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '锡林郭勒盟',
#     'citycode': 'CN15250000000000'},
#    {'name': '赤峰',
#     'conNum': '9',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '赤峰市',
#     'citycode': 'CN15040000000000'},
#    {'name': '巴彦淖尔',
#     'conNum': '8',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '巴彦淖尔市',
#     'citycode': 'CN15080000000000'},
#    {'name': '呼和浩特',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '呼和浩特市',
#     'citycode': 'CN15010000000000'},
#    {'name': '通辽',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '通辽市',
#     'citycode': 'CN15050000000000'},
#    {'name': '呼伦贝尔',
#     'conNum': '7',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '呼伦贝尔市',
#     'citycode': 'CN15070000000000'},
#    {'name': '乌兰察布',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '乌兰察布市',
#     'citycode': 'CN15090000000000'},
#    {'name': '乌海',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '乌海市',
#     'citycode': 'CN15030000000000'},
#    {'name': '兴安盟',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '兴安盟',
#     'citycode': 'CN15220000000000'}]},
#  {'name': '台湾',
#   'ename': 'taiwan',
#   'value': '30',
#   'conadd': 2,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '1',
#   'cureNum': '5',
#   'adddaily': {'conadd': '+2',
#    'deathadd': '+0',
#    'cureadd': '+0',
#    'conadd_n': 2,
#    'deathadd_n': 0,
#    'cureadd_n': 0},
#   'city': []},
#  {'name': '澳门',
#   'ename': 'aomen',
#   'value': '10',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '6',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+0',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 0},
#   'city': []},
#  {'name': '香港',
#   'ename': 'xianggang',
#   'value': '81',
#   'conadd': 7,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '2',
#   'cureNum': '19',
#   'adddaily': {'conadd': '+7',
#    'deathadd': '+0',
#    'cureadd': '+7',
#    'conadd_n': 7,
#    'deathadd_n': 0,
#    'cureadd_n': 7},
#   'city': []},
#  {'name': '贵州',
#   'ename': 'guizhou',
#   'value': '146',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '2',
#   'cureNum': '103',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+1',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 1},
#   'city': [{'name': '贵阳',
#     'conNum': '36',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '23',
#     'deathNum': '1',
#     'mapName': '贵阳市',
#     'citycode': 'CN52010000000000'},
#    {'name': '遵义',
#     'conNum': '32',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'mapName': '遵义市',
#     'citycode': 'CN52030000000000'},
#    {'name': '六盘水',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '8',
#     'deathNum': '1',
#     'mapName': '六盘水市',
#     'citycode': 'CN52020000000000'},
#    {'name': '安顺',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '安顺市',
#     'citycode': 'CN52040000000000'},
#    {'name': '毕节',
#     'conNum': '23',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'mapName': '毕节市',
#     'citycode': 'CN52050000000000'},
#    {'name': '铜仁',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '铜仁市',
#     'citycode': 'CN52060000000000'},
#    {'name': '黔东南州',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'mapName': '黔东南苗族侗族自治州',
#     'citycode': 'CN52260000000000'},
#    {'name': '黔南州',
#     'conNum': '17',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '13',
#     'deathNum': '0',
#     'mapName': '黔南布依族苗族自治州',
#     'citycode': 'CN52270000000000'},
#    {'name': '黔西南州',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '黔西南布依族苗族自治州',
#     'citycode': 'CN52230000000000'}]},
#  {'name': '西藏',
#   'ename': 'xizang',
#   'value': '1',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '1',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+0',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 0},
#   'city': [{'name': '拉萨',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '拉萨市',
#     'citycode': 'CN54010000000000'}]},
#  {'name': '青海',
#   'ename': 'qinghai',
#   'value': '18',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '18',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+0',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 0},
#   'city': [{'name': '西宁',
#     'conNum': '15',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '15',
#     'deathNum': '0',
#     'mapName': '西宁市',
#     'citycode': 'CN63010000000000'},
#    {'name': '海北州',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '海北藏族自治州',
#     'citycode': 'CN63220000000000'}]},
#  {'name': '新疆',
#   'ename': 'xinjiang',
#   'value': '76',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '2',
#   'cureNum': '30',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+2',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 2},
#   'city': [{'name': '乌鲁木齐',
#     'conNum': '23',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '13',
#     'deathNum': '0',
#     'mapName': '乌鲁木齐市',
#     'citycode': 'CN65010000000000'},
#    {'name': '伊犁州',
#     'conNum': '18',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '6',
#     'deathNum': '0',
#     'mapName': '伊犁哈萨克自治州',
#     'citycode': 'CN65400000000000'},
#    {'name': '昌吉',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '昌吉回族自治州',
#     'citycode': 'CN65230000000000'},
#    {'name': '吐鲁番',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '吐鲁番市',
#     'citycode': 'CN65040000000000'},
#    {'name': '巴州',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'mapName': '巴音郭楞蒙古自治州',
#     'citycode': 'CN65280000000000'},
#    {'name': '阿克苏',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '阿克苏地区',
#     'citycode': 'CN65290000000000'},
#    {'name': '第四师',
#     'conNum': '10',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''},
#    {'name': '五家渠市',
#     'conNum': '2',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'mapName': '五家渠市',
#     'citycode': 'CN65900400000000'},
#    {'name': '石河子',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '1',
#     'mapName': '石河子市',
#     'citycode': 'CN65900100000000'},
#    {'name': '第七师',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '新疆生产建设兵团第七师',
#     'citycode': ''},
#    {'name': '第九师',
#     'conNum': '4',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '1',
#     'mapName': '新疆生产建设兵团第九师',
#     'citycode': ''},
#    {'name': '第十二师',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''}]},
#  {'name': '宁夏',
#   'ename': 'ningxia',
#   'value': '71',
#   'conadd': 0,
#   'hejian': '',
#   'susNum': '0',
#   'deathNum': '0',
#   'cureNum': '58',
#   'adddaily': {'conadd': '+0',
#    'deathadd': '+0',
#    'cureadd': '+1',
#    'conadd_n': 0,
#    'deathadd_n': 0,
#    'cureadd_n': 1},
#   'city': [{'name': '银川',
#     'conNum': '33',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '29',
#     'deathNum': '0',
#     'mapName': '银川市',
#     'citycode': 'CN64010000000000'},
#    {'name': '石嘴山',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '石嘴山市',
#     'citycode': 'CN64020000000000'},
#    {'name': '吴忠',
#     'conNum': '28',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '20',
#     'deathNum': '0',
#     'mapName': '吴忠市',
#     'citycode': 'CN64030000000000'},
#    {'name': '固原',
#     'conNum': '5',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'mapName': '固原市',
#     'citycode': 'CN64040000000000'},
#    {'name': '中卫',
#     'conNum': '3',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'mapName': '中卫市',
#     'citycode': 'CN64050000000000'},
#    {'name': '宁东',
#     'conNum': '1',
#     'conadd': 0,
#     'hejian': '',
#     'susNum': '0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'mapName': '',
#     'citycode': ''}]}]

# %%
list = []
for province_ in data['list']:
    for city in province_['city']:
        num = {'name':city['name'],'province':province_['name'],'value': int(city['conNum'])}
        list.append(num)

# %%
city = pd.DataFrame(list).set_index('name')
city = city.sort_values(by='value',ascending=False)

# %%
city.head()
# Out:
#      province  value
# name
# 武汉         湖北  47071
# 孝感         湖北   3482
# 黄冈         湖北   2904
# 荆州         湖北   1576
# 鄂州         湖北   1385

# %%
world.to_csv('world_infected.csv')
province.to_csv('province_infected.csv')
city.to_csv('city_infected.csv')
